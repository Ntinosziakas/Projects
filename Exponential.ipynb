# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

filedata = np.genfromtxt('Exponential.txt', delimiter=',')
filedata = filedata.astype('float32')
#print(np.round((filedata),4))
print("----------------------------------------------------------------------------")



print("Mean = ", np.round(np.average(filedata),2))
print("Variance = ", np.round(np.var(filedata),2))
print("Standard Deviation = ", np.round(np.std(filedata),2))
print("Max = ", np.round(np.max(filedata),4))
print("Min = ", np.round(np.min(filedata),4))
max = np.round(np.max(filedata),4)
min = np.round(np.min(filedata),4)
range = max - min
print("Range = ", np.round(range,4))
med = np.median(filedata)
print("Median =", np.round(med,4))
filedata[filedata > np.average(filedata)]
sum=np.count_nonzero(filedata)
ba=np.count_nonzero(filedata > np.average(filedata))
tba=ba/sum

print("The number of data which was more than the average :",np.count_nonzero(filedata > np.average(filedata)),"=",np.round(tba,4),"=",np.round(100*tba,2),"%")
print("The number of data which was less than the average :",np.count_nonzero(filedata < np.average(filedata)),"=",np.round(1-tba,4),"=",np.round(100*(1-tba),2),"%")
print("----------------------------------------------------------------------------")

# Sort Data
sfiledata=np.sort(filedata)

# Plot Data
plt.plot(sfiledata)
plt.title("Line Plot") 
plt.show()

# Histogram
plt.hist(sfiledata)
plt.title("Histogram")
plt.show()

# Boxplot
plt.boxplot(sfiledata)
plt.title("Boxplot") 
plt.show()

plt.bar(filedata, height=1+max, width=0.0088)
plt.title("Bar Chart") 
plt.show()
# Out:
# ----------------------------------------------------------------------------
# Mean =  0.99
# Variance =  0.99
# Standard Deviation =  1.0
# Max =  6.3785
# Min =  0.0003
# Range =  6.3782
# Median = 0.6481
# The number of data which was more than the average : 359 = 0.3594 = 35.94 %
# The number of data which was less than the average : 640 = 0.6406 = 64.06 %
# ----------------------------------------------------------------------------
